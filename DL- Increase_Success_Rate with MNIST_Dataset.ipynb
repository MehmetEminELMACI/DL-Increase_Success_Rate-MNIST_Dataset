# %%
import tensorflow as tf

mnist= tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images= train_images.reshape(60000, 784)
test_images= test_images.reshape(10000, 784)
test_images= test_images.astype('float32')
train_images= train_images.astype('float32')
test_images/= 255
train_images/= 255
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(64, activation='relu', input_shape=(784,)),
                             tf.keras.layers.Dense(64, activation='relu'),
                             tf.keras.layers.Dense(10, activation='softmax'),])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_images, train_labels, batch_size=128, epochs=40, verbose=1, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/40
# 469/469 [==============================] - 17s 18ms/step - loss: 0.7042 - accuracy: 0.7999 - val_loss: 0.1886 - val_accuracy: 0.9458
# Epoch 2/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1724 - accuracy: 0.9506 - val_loss: 0.1428 - val_accuracy: 0.9580
# Epoch 3/40
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1215 - accuracy: 0.9639 - val_loss: 0.1150 - val_accuracy: 0.9655
# Epoch 4/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0932 - accuracy: 0.9719 - val_loss: 0.1015 - val_accuracy: 0.9678
# Epoch 5/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0805 - accuracy: 0.9767 - val_loss: 0.0908 - val_accuracy: 0.9717
# Epoch 6/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0640 - accuracy: 0.9809 - val_loss: 0.0878 - val_accuracy: 0.9722
# Epoch 7/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0568 - accuracy: 0.9838 - val_loss: 0.0850 - val_accuracy: 0.9752
# Epoch 8/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0486 - accuracy: 0.9855 - val_loss: 0.0795 - val_accuracy: 0.9762
# Epoch 9/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0423 - accuracy: 0.9878 - val_loss: 0.0890 - val_accuracy: 0.9748
# Epoch 10/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0368 - accuracy: 0.9883 - val_loss: 0.0850 - val_accuracy: 0.9744
# Epoch 11/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0322 - accuracy: 0.9906 - val_loss: 0.0788 - val_accuracy: 0.9770
# Epoch 12/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0254 - accuracy: 0.9929 - val_loss: 0.0874 - val_accuracy: 0.9737
# Epoch 13/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0226 - accuracy: 0.9932 - val_loss: 0.0910 - val_accuracy: 0.9743
# Epoch 14/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0221 - accuracy: 0.9934 - val_loss: 0.0891 - val_accuracy: 0.9759
# Epoch 15/40
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0183 - accuracy: 0.9943 - val_loss: 0.0858 - val_accuracy: 0.9772
# Epoch 16/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.1022 - val_accuracy: 0.9749
# Epoch 17/40
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0191 - accuracy: 0.9937 - val_loss: 0.0895 - val_accuracy: 0.9771
# Epoch 18/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0129 - accuracy: 0.9961 - val_loss: 0.1062 - val_accuracy: 0.9735
# Epoch 19/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0102 - accuracy: 0.9970 - val_loss: 0.1135 - val_accuracy: 0.9749
# Epoch 20/40
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0107 - accuracy: 0.9965 - val_loss: 0.1030 - val_accuracy: 0.9750
# Epoch 21/40
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.1112 - val_accuracy: 0.9731
# Epoch 22/40
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.1093 - val_accuracy: 0.9762
# Epoch 23/40
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.1239 - val_accuracy: 0.9722
# Epoch 24/40
# 469/469 [==============================] - 4s 10ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.1179 - val_accuracy: 0.9760
# Epoch 25/40
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.1260 - val_accuracy: 0.9746
# Epoch 26/40
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0096 - accuracy: 0.9969 - val_loss: 0.1176 - val_accuracy: 0.9761
# Epoch 27/40
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.1190 - val_accuracy: 0.9769
# Epoch 28/40
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.1259 - val_accuracy: 0.9769
# Epoch 29/40
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.1244 - val_accuracy: 0.9751
# Epoch 30/40
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.1227 - val_accuracy: 0.9773
# Epoch 31/40
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.1243 - val_accuracy: 0.9784
# Epoch 32/40
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.1494 - val_accuracy: 0.9726
# Epoch 33/40
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.1390 - val_accuracy: 0.9727
# Epoch 34/40
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.1264 - val_accuracy: 0.9785
# Epoch 35/40
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.1868 - val_accuracy: 0.9693
# Epoch 36/40
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.1473 - val_accuracy: 0.9758
# Epoch 37/40
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.1383 - val_accuracy: 0.9776
# Epoch 38/40
# 469/469 [==============================] - 5s 12ms/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 0.1405 - val_accuracy: 0.9782
# Epoch 39/40
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.1446 - val_accuracy: 0.9773
# Epoch 40/40
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.1531 - val_accuracy: 0.9765

# %%
_, accuracy=model.evaluate(test_images, test_labels)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1531 - accuracy: 0.9765
# Accuracy: 97.65

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# # Add layers and Increasing the number of neurons

# %%
import tensorflow as tf

mnist= tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images= train_images.reshape(60000, 784)
test_images= test_images.reshape(10000, 784)
test_images= test_images.astype('float32')
train_images= train_images.astype('float32')
test_images/= 255
train_images/= 255
model = tf.keras.Sequential([
                             tf.keras.layers.Dense(512, activation='relu', input_shape=(784,)),
                             tf.keras.layers.Dense(512, activation='relu'),
                             tf.keras.layers.Dense(512, activation='relu'),
                             tf.keras.layers.Dense(10, activation='softmax'),])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_images, train_labels, batch_size=128, epochs=40, verbose=1, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/40
# 469/469 [==============================] - 51s 105ms/step - loss: 0.3942 - accuracy: 0.8825 - val_loss: 0.1152 - val_accuracy: 0.9640
# Epoch 2/40
# 469/469 [==============================] - 45s 95ms/step - loss: 0.0837 - accuracy: 0.9742 - val_loss: 0.0886 - val_accuracy: 0.9709
# Epoch 3/40
# 469/469 [==============================] - 47s 100ms/step - loss: 0.0539 - accuracy: 0.9840 - val_loss: 0.0723 - val_accuracy: 0.9789
# Epoch 4/40
# 469/469 [==============================] - 50s 106ms/step - loss: 0.0364 - accuracy: 0.9886 - val_loss: 0.0724 - val_accuracy: 0.9798
# Epoch 5/40
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0313 - accuracy: 0.9902 - val_loss: 0.0771 - val_accuracy: 0.9796
# Epoch 6/40
# 469/469 [==============================] - 46s 99ms/step - loss: 0.0232 - accuracy: 0.9930 - val_loss: 0.0700 - val_accuracy: 0.9817
# Epoch 7/40
# 469/469 [==============================] - 41s 87ms/step - loss: 0.0198 - accuracy: 0.9934 - val_loss: 0.0888 - val_accuracy: 0.9782
# Epoch 8/40
# 469/469 [==============================] - 45s 97ms/step - loss: 0.0229 - accuracy: 0.9924 - val_loss: 0.0727 - val_accuracy: 0.9818
# Epoch 9/40
# 469/469 [==============================] - 52s 110ms/step - loss: 0.0164 - accuracy: 0.9947 - val_loss: 0.0969 - val_accuracy: 0.9773
# Epoch 10/40
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0153 - accuracy: 0.9953 - val_loss: 0.0824 - val_accuracy: 0.9803
# Epoch 11/40
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 0.0836 - val_accuracy: 0.9801
# Epoch 12/40
# 469/469 [==============================] - 53s 114ms/step - loss: 0.0129 - accuracy: 0.9955 - val_loss: 0.0861 - val_accuracy: 0.9810
# Epoch 13/40
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.0770 - val_accuracy: 0.9826
# Epoch 14/40
# 469/469 [==============================] - 44s 95ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.0936 - val_accuracy: 0.9821
# Epoch 15/40
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0180 - accuracy: 0.9953 - val_loss: 0.0797 - val_accuracy: 0.9839
# Epoch 16/40
# 469/469 [==============================] - 53s 113ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0978 - val_accuracy: 0.9798
# Epoch 17/40
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.0853 - val_accuracy: 0.9826
# Epoch 18/40
# 469/469 [==============================] - 52s 110ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.0904 - val_accuracy: 0.9808
# Epoch 19/40
# 469/469 [==============================] - 53s 114ms/step - loss: 0.0096 - accuracy: 0.9972 - val_loss: 0.1005 - val_accuracy: 0.9821
# Epoch 20/40
# 469/469 [==============================] - 37s 79ms/step - loss: 0.0091 - accuracy: 0.9974 - val_loss: 0.1008 - val_accuracy: 0.9820
# Epoch 21/40
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0107 - accuracy: 0.9969 - val_loss: 0.0927 - val_accuracy: 0.9830
# Epoch 22/40
# 469/469 [==============================] - 32s 69ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.1016 - val_accuracy: 0.9835
# Epoch 23/40
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0120 - accuracy: 0.9972 - val_loss: 0.0948 - val_accuracy: 0.9823
# Epoch 24/40
# 469/469 [==============================] - 32s 69ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.1136 - val_accuracy: 0.9780
# Epoch 25/40
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.1097 - val_accuracy: 0.9816
# Epoch 26/40
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0105 - accuracy: 0.9971 - val_loss: 0.0791 - val_accuracy: 0.9854
# Epoch 27/40
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.1244 - val_accuracy: 0.9811
# Epoch 28/40
# 469/469 [==============================] - 33s 69ms/step - loss: 0.0065 - accuracy: 0.9984 - val_loss: 0.0889 - val_accuracy: 0.9855
# Epoch 29/40
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0825 - val_accuracy: 0.9840
# Epoch 30/40
# 469/469 [==============================] - 32s 69ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.0884 - val_accuracy: 0.9827
# Epoch 31/40
# 469/469 [==============================] - 32s 69ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0944 - val_accuracy: 0.9831
# Epoch 32/40
# 469/469 [==============================] - 32s 69ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0951 - val_accuracy: 0.9825
# Epoch 33/40
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.1206 - val_accuracy: 0.9770
# Epoch 34/40
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0147 - accuracy: 0.9962 - val_loss: 0.0924 - val_accuracy: 0.9854
# Epoch 35/40
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0918 - val_accuracy: 0.9841
# Epoch 36/40
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0086 - accuracy: 0.9981 - val_loss: 0.0928 - val_accuracy: 0.9839
# Epoch 37/40
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0942 - val_accuracy: 0.9821
# Epoch 38/40
# 469/469 [==============================] - 32s 69ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1039 - val_accuracy: 0.9844
# Epoch 39/40
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.1029 - val_accuracy: 0.9823
# Epoch 40/40
# 469/469 [==============================] - 32s 69ms/step - loss: 0.0080 - accuracy: 0.9979 - val_loss: 0.1157 - val_accuracy: 0.9834

# %%
_, accuracy=model.evaluate(test_images, test_labels)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 313/313 [==============================] - 4s 12ms/step - loss: 0.1157 - accuracy: 0.9834
# Accuracy: 98.34

# %% [markdown]
# # Add Conv2D , MaxPooling and Falatten Layers
#
# #### CNN (Convoloutional Neural Networks) deep learning network used to recognize pictures.
# #### Conc2D --> The layer that allows us to read pictures with CNN
# #### MaxPooling --> is a pooling operation that calculates the maximum, or largest, value in each patch of each feature map.
# #### Flatten --> Combines layers (such as reducing 2 dimensions to 1 dimension)

# %%
import tensorflow as tf 

mnist= tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images= train_images.reshape(60000, 28, 28, 1)
test_images= test_images.reshape(10000, 28, 28, 1)

train_images, test_images= train_images/255.0,test_images/255.0

model = tf.keras.Sequential([
                             tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)), 
                             tf.keras.layers.MaxPooling2D(2,2), 
                             tf.keras.layers.Flatten(),
                             tf.keras.layers.Dense(100, activation='relu'),
                             tf.keras.layers.Dense(10, activation='softmax')])
model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.01, momentum=0.9), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history =model.fit(train_images, train_labels, batch_size=32, epochs=10, verbose=1, validation_data=(test_images, test_labels))
# lr=learning rate
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 108s 56ms/step - loss: 0.4410 - accuracy: 0.8656 - val_loss: 0.1018 - val_accuracy: 0.9664
# Epoch 2/10
# 1875/1875 [==============================] - 92s 49ms/step - loss: 0.0824 - accuracy: 0.9750 - val_loss: 0.0613 - val_accuracy: 0.9793
# Epoch 3/10
# 1875/1875 [==============================] - 89s 47ms/step - loss: 0.0495 - accuracy: 0.9853 - val_loss: 0.0442 - val_accuracy: 0.9848
# Epoch 4/10
# 1875/1875 [==============================] - 106s 57ms/step - loss: 0.0328 - accuracy: 0.9903 - val_loss: 0.0440 - val_accuracy: 0.9858
# Epoch 5/10
# 1875/1875 [==============================] - 91s 48ms/step - loss: 0.0252 - accuracy: 0.9924 - val_loss: 0.0519 - val_accuracy: 0.9836
# Epoch 6/10
# 1875/1875 [==============================] - 76s 41ms/step - loss: 0.0197 - accuracy: 0.9941 - val_loss: 0.0425 - val_accuracy: 0.9848
# Epoch 7/10
# 1875/1875 [==============================] - 83s 44ms/step - loss: 0.0134 - accuracy: 0.9963 - val_loss: 0.0424 - val_accuracy: 0.9870
# Epoch 8/10
# 1875/1875 [==============================] - 91s 49ms/step - loss: 0.0097 - accuracy: 0.9974 - val_loss: 0.0414 - val_accuracy: 0.9873
# Epoch 9/10
# 1875/1875 [==============================] - 77s 41ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.0438 - val_accuracy: 0.9874
# Epoch 10/10
# 1875/1875 [==============================] - 112s 60ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.0466 - val_accuracy: 0.9869

# %%
_, accuracy=model.evaluate(test_images, test_labels)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 313/313 [==============================] - 4s 13ms/step - loss: 0.0466 - accuracy: 0.9869
# Accuracy: 98.69

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# # Add Conv2D layers and Reduce epochs

# %%
import tensorflow as tf 

mnist= tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images= train_images.reshape(60000, 28, 28, 1)
test_images= test_images.reshape(10000, 28, 28, 1)

train_images, test_images= train_images/255.0,test_images/255.0

model = tf.keras.Sequential([
                             tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
                             tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
                             tf.keras.layers.MaxPooling2D(2,2),
                             tf.keras.layers.Flatten(),
                             tf.keras.layers.Dense(100, activation='relu'),
                             tf.keras.layers.Dense(10, activation='softmax')])
model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.01, momentum=0.9), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history =model.fit(train_images, train_labels, batch_size=32, epochs=15, verbose=1, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 732s 389ms/step - loss: 0.4177 - accuracy: 0.8692 - val_loss: 0.0582 - val_accuracy: 0.9819
# Epoch 2/15
# 1875/1875 [==============================] - 570s 304ms/step - loss: 0.0551 - accuracy: 0.9837 - val_loss: 0.0378 - val_accuracy: 0.9880
# Epoch 3/15
# 1875/1875 [==============================] - 618s 330ms/step - loss: 0.0347 - accuracy: 0.9890 - val_loss: 0.0363 - val_accuracy: 0.9894
# Epoch 4/15
# 1875/1875 [==============================] - 432s 230ms/step - loss: 0.0204 - accuracy: 0.9943 - val_loss: 0.0400 - val_accuracy: 0.9879
# Epoch 5/15
# 1875/1875 [==============================] - 543s 290ms/step - loss: 0.0184 - accuracy: 0.9944 - val_loss: 0.0374 - val_accuracy: 0.9886
# Epoch 6/15
# 1875/1875 [==============================] - 532s 284ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.0411 - val_accuracy: 0.9881
# Epoch 7/15
# 1875/1875 [==============================] - 1139s 608ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0407 - val_accuracy: 0.9886
# Epoch 8/15
# 1875/1875 [==============================] - 708s 378ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0368 - val_accuracy: 0.9904
# Epoch 9/15
# 1875/1875 [==============================] - 443s 236ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0387 - val_accuracy: 0.9901
# Epoch 10/15
# 1875/1875 [==============================] - 404s 216ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0394 - val_accuracy: 0.9900
# Epoch 11/15
# 1875/1875 [==============================] - 432s 230ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0386 - val_accuracy: 0.9913
# Epoch 12/15
# 1875/1875 [==============================] - 442s 236ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0409 - val_accuracy: 0.9909
# Epoch 13/15
# 1875/1875 [==============================] - 415s 221ms/step - loss: 6.3470e-04 - accuracy: 0.9999 - val_loss: 0.0433 - val_accuracy: 0.9907
# Epoch 14/15
# 1875/1875 [==============================] - 459s 245ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0400 - val_accuracy: 0.9918
# Epoch 15/15
# 1875/1875 [==============================] - 401s 214ms/step - loss: 4.0951e-04 - accuracy: 0.9999 - val_loss: 0.0408 - val_accuracy: 0.9913

# %%
_, accuracy=model.evaluate(test_images, test_labels)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 313/313 [==============================] - 22s 68ms/step - loss: 0.0408 - accuracy: 0.9913
# Accuracy: 99.13

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# # Add Dropout layer
# #### Dropout --> It randomly deletes some columns. It prevents us from loving one column more and not loving another.

# %%
import tensorflow as tf 

mnist= tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images= train_images.reshape(60000, 28, 28, 1)
test_images= test_images.reshape(10000, 28, 28, 1)

train_images, test_images= train_images/255.0,test_images/255.0

model = tf.keras.Sequential([
                             tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
                             tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
                             tf.keras.layers.MaxPooling2D(2,2),
                             tf.keras.layers.Flatten(),
                             tf.keras.layers.Dense(100, activation='relu'),
                             tf.keras.layers.Dropout(0.5),
                             tf.keras.layers.Dense(10, activation='softmax')])
model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.01, momentum=0.9), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history =model.fit(train_images, train_labels, batch_size=32, epochs=15, verbose=1, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 421s 214ms/step - loss: 0.5408 - accuracy: 0.8260 - val_loss: 0.0603 - val_accuracy: 0.9802
# Epoch 2/15
# 1875/1875 [==============================] - 397s 212ms/step - loss: 0.1085 - accuracy: 0.9670 - val_loss: 0.0444 - val_accuracy: 0.9855
# Epoch 3/15
# 1875/1875 [==============================] - 399s 213ms/step - loss: 0.0757 - accuracy: 0.9770 - val_loss: 0.0343 - val_accuracy: 0.9883
# Epoch 4/15
# 1875/1875 [==============================] - 399s 213ms/step - loss: 0.0563 - accuracy: 0.9823 - val_loss: 0.0360 - val_accuracy: 0.9883
# Epoch 5/15
# 1875/1875 [==============================] - 397s 212ms/step - loss: 0.0525 - accuracy: 0.9847 - val_loss: 0.0322 - val_accuracy: 0.9905
# Epoch 6/15
# 1875/1875 [==============================] - 398s 212ms/step - loss: 0.0454 - accuracy: 0.9858 - val_loss: 0.0319 - val_accuracy: 0.9895
# Epoch 7/15
# 1875/1875 [==============================] - 404s 215ms/step - loss: 0.0368 - accuracy: 0.9883 - val_loss: 0.0311 - val_accuracy: 0.9901
# Epoch 8/15
# 1875/1875 [==============================] - 406s 216ms/step - loss: 0.0361 - accuracy: 0.9882 - val_loss: 0.0326 - val_accuracy: 0.9907
# Epoch 9/15
# 1875/1875 [==============================] - 409s 218ms/step - loss: 0.0321 - accuracy: 0.9890 - val_loss: 0.0326 - val_accuracy: 0.9904
# Epoch 10/15
# 1875/1875 [==============================] - 413s 220ms/step - loss: 0.0250 - accuracy: 0.9914 - val_loss: 0.0315 - val_accuracy: 0.9910
# Epoch 11/15
# 1875/1875 [==============================] - 409s 218ms/step - loss: 0.0260 - accuracy: 0.9919 - val_loss: 0.0321 - val_accuracy: 0.9921
# Epoch 12/15
# 1875/1875 [==============================] - 409s 218ms/step - loss: 0.0245 - accuracy: 0.9917 - val_loss: 0.0316 - val_accuracy: 0.9915
# Epoch 13/15
# 1875/1875 [==============================] - 445s 237ms/step - loss: 0.0220 - accuracy: 0.9926 - val_loss: 0.0332 - val_accuracy: 0.9915
# Epoch 14/15
# 1875/1875 [==============================] - 1094s 584ms/step - loss: 0.0211 - accuracy: 0.9933 - val_loss: 0.0414 - val_accuracy: 0.9897
# Epoch 15/15
# 1875/1875 [==============================] - 495s 264ms/step - loss: 0.0167 - accuracy: 0.9948 - val_loss: 0.0373 - val_accuracy: 0.9902

# %%
_, accuracy=model.evaluate(test_images, test_labels)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 313/313 [==============================] - 22s 66ms/step - loss: 0.0373 - accuracy: 0.9902
# Accuracy: 99.02

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Train and test data got closer to each other. This could trust.

# %% [markdown]
# # Add BatchNormalization layer
# #### BatchNormalization --> It normalizes after each data. (Normally data is scattered)

# %%
import tensorflow as tf 

mnist= tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images= train_images.reshape(60000, 28, 28, 1)
test_images= test_images.reshape(10000, 28, 28, 1)

train_images, test_images= train_images/255.0,test_images/255.0

model = tf.keras.Sequential([
                             tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
                             tf.keras.layers.BatchNormalization(), 
                             tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
                             tf.keras.layers.MaxPooling2D(2,2),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Flatten(),
                             tf.keras.layers.Dense(100, activation='relu'),
                             tf.keras.layers.BatchNormalization(),
                             tf.keras.layers.Dense(10, activation='softmax')])
model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.01, momentum=0.9), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history =model.fit(train_images, train_labels, batch_size=32, epochs=15, verbose=1, validation_data=(test_images, test_labels))
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 604s 255ms/step - loss: 0.1818 - accuracy: 0.9457 - val_loss: 0.0460 - val_accuracy: 0.9856
# Epoch 2/15
# 1875/1875 [==============================] - 477s 254ms/step - loss: 0.0392 - accuracy: 0.9888 - val_loss: 0.0322 - val_accuracy: 0.9892
# Epoch 3/15
# 1875/1875 [==============================] - 476s 254ms/step - loss: 0.0233 - accuracy: 0.9926 - val_loss: 0.0284 - val_accuracy: 0.9905
# Epoch 4/15
# 1875/1875 [==============================] - 477s 254ms/step - loss: 0.0155 - accuracy: 0.9953 - val_loss: 0.0278 - val_accuracy: 0.9919
# Epoch 5/15
# 1875/1875 [==============================] - 481s 257ms/step - loss: 0.0088 - accuracy: 0.9978 - val_loss: 0.0274 - val_accuracy: 0.9914
# Epoch 6/15
# 1875/1875 [==============================] - 485s 259ms/step - loss: 0.0062 - accuracy: 0.9985 - val_loss: 0.0255 - val_accuracy: 0.9915
# Epoch 7/15
# 1875/1875 [==============================] - 485s 259ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.0263 - val_accuracy: 0.9914
# Epoch 8/15
# 1875/1875 [==============================] - 485s 259ms/step - loss: 0.0044 - accuracy: 0.9988 - val_loss: 0.0270 - val_accuracy: 0.9923
# Epoch 9/15
# 1875/1875 [==============================] - 483s 258ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 0.0305 - val_accuracy: 0.9913
# Epoch 10/15
# 1875/1875 [==============================] - 482s 257ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0271 - val_accuracy: 0.9928
# Epoch 11/15
# 1875/1875 [==============================] - 484s 258ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0271 - val_accuracy: 0.9932
# Epoch 12/15
# 1875/1875 [==============================] - 485s 259ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.0279 - val_accuracy: 0.9917
# Epoch 13/15
# 1875/1875 [==============================] - 488s 260ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0323 - val_accuracy: 0.9912
# Epoch 14/15
# 1875/1875 [==============================] - 485s 259ms/step - loss: 9.5256e-04 - accuracy: 0.9999 - val_loss: 0.0299 - val_accuracy: 0.9918
# Epoch 15/15
# 1875/1875 [==============================] - 486s 259ms/step - loss: 9.4311e-04 - accuracy: 0.9999 - val_loss: 0.0283 - val_accuracy: 0.9922

# %%
_, accuracy=model.evaluate(test_images, test_labels)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 313/313 [==============================] - 22s 70ms/step - loss: 0.0283 - accuracy: 0.9922
# Accuracy: 99.22

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
